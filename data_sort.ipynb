# %%
#there are 1.8 million trip records with 263 taxi zones

# %%
import pandas as pd
#import geopandas as gpd

# Load trip data
df_trips = pd.read_parquet("Data/fhvhv_tripdata_2022-11.parquet")

# Load zone mapping
df_zones = pd.read_csv("Data/tlc-nyc-taxi-zones/taxi_zones.csv")

# maybe could use this for visualization later on
#gdf_zones = gpd.read_file("Data/tlc-nyc-taxi-zones/NYC Taxi Zones.geojson")

# Confirm it worked
#print("Trips:", df_trips.shape)
#print("Zones:", df_zones.shape)

# %%
# Detect column name case (Zone vs zone)
zone_col = 'Zone' if 'Zone' in df_zones.columns else 'zone'

# Lowercase for search
df_zones['zone_lower'] = df_zones[zone_col].str.lower()

#function to get location id and give option to choose from values if there are more than 1
#for example, if someone types "east" it will show all the locations with east and then ask user to pick one
def get_location_id(zone_name):
    matches = []
    zone_name = zone_name.strip().lower()

    for _, row in df_zones.iterrows():
        if zone_name in row['zone_lower']:
            matches.append((row['LocationID'], row[zone_col]))

    if len(matches) == 0:
        print(f"No match found for '{zone_name}'")
        return None
    elif len(matches) == 1:
        loc_id, name = matches[0]
        print(f"Match found: {name} → LocationID: {loc_id}")
        return loc_id
    else:
        print(f"\nMultiple matches for '{zone_name}':")
        for i, (loc_id, name) in enumerate(matches):
            print(f"  {i+1}. {name} (LocationID: {loc_id})")
        selection = input("Enter the number of the correct match: ").strip()
        if selection.isdigit():
            index = int(selection) - 1
            if 0 <= index < len(matches):
                return matches[index][0]
        print("Invalid selection.")
        return None

# save LocationIDs for future algorithms
# Loop until valid start location is found
start_id = None
while start_id is None:
    start_name = input("Enter your START location: ").strip().lower()
    start_id = get_location_id(start_name)

# Loop until valid end location is found
end_id = None
while end_id is None:
    end_name = input("Enter your END location: ").strip().lower()
    end_id = get_location_id(end_name)
#check
#print(f"\nStart ID: {start_id}")
#print(f"End ID: {end_id}")

#check
#print(f"\nStart ID: {start_id}")
#print(f"End ID: {end_id}")
# Out:
# Match found: Clinton East → LocationID: 48
# Match found: Co-Op City → LocationID: 51

# %%
#first lets sort the data by id so that we can use the search algorithm
#the built in tim sort takes like O(nlogn)
df_trips.sort_values(by=['PULocationID', 'DOLocationID'], inplace=True)
df_trips.reset_index(drop=True, inplace=True)  #Reset index for easier iteration

#map license codes to company names
company_map = {
    'HV0002': 'Juno',
    'HV0003': 'Uber',
    'HV0004': 'Via',
    'HV0005': 'Lyft'
}

# get zone names from LocationID
zone_col = 'Zone' if 'Zone' in df_zones.columns else 'zone'
zone_lookup = dict(zip(df_zones['LocationID'], df_zones[zone_col]))

start_zone = zone_lookup.get(start_id, f"ID {start_id}")
end_zone = zone_lookup.get(end_id, f"ID {end_id}")

#since now the data is sorted, lets run the data through a binary search algorithm
def lower_bound(trips, start_id, end_id):
    low = 0
    high = len(trips) - 1
    result = -1

    while low <= high:
        mid = (low + high) // 2
        pickup = trips.iloc[mid]['PULocationID']
        dropoff = trips.iloc[mid]['DOLocationID']

        if (pickup, dropoff) < (start_id, end_id):
            low = mid + 1
        else:
            if (pickup, dropoff) == (start_id, end_id):
                result = mid  #save first match index
            high = mid - 1

    return result

#collecting all values that match start and end location
def collect_all_matches(trips, start_idx, start_id, end_id):
    results = []
    i = start_idx
    while i < len(trips):
        row = trips.iloc[i]
        if row['PULocationID'] == start_id and row['DOLocationID'] == end_id:
            company = company_map.get(row['hvfhs_license_num'], 'Unknown')
            results.append((row['pickup_datetime'], row['dropoff_datetime'], company))
        else:
            break  #since it's sorted, we can stop early
        i += 1
    return results

#using everything to get results
#binary search
first_match_idx = lower_bound(df_trips, start_id, end_id)

if first_match_idx != -1:
    matches = collect_all_matches(df_trips, first_match_idx, start_id, end_id)
    print(f"\nFound {len(matches)} matching trips from {start_zone} to {end_zone}:\n")
    for i, (pickup, dropoff, company) in enumerate(matches, 1):
        print(f"{i}. From: {start_zone}  →  To: {end_zone}  |  Pickup: {pickup}  |  Dropoff: {dropoff}  |  Company: {company}")
else:
    print(f"No matching trips found from {start_zone} to {end_zone}.")
# Out:
# Found 85 matching trips from Clinton East to Co-Op City:
#
# 1. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-02 21:20:51  |  Dropoff: 2022-11-02 21:51:33  |  Company: Uber
# 2. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-03 00:11:33  |  Dropoff: 2022-11-03 00:34:03  |  Company: Uber
# 3. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-03 21:12:40  |  Dropoff: 2022-11-03 21:48:10  |  Company: Uber
# 4. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-04 01:47:38  |  Dropoff: 2022-11-04 02:14:32  |  Company: Uber
# 5. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-04 07:11:56  |  Dropoff: 2022-11-04 07:52:54  |  Company: Uber
# 6. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-04 10:58:41  |  Dropoff: 2022-11-04 11:28:33  |  Company: Uber
# 7. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-05 01:53:13  |  Dropoff: 2022-11-05 02:35:07  |  Company: Lyft
# 8. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-05 02:06:29  |  Dropoff: 2022-11-05 02:34:06  |  Company: Lyft
# 9. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-05 07:11:52  |  Dropoff: 2022-11-05 07:37:14  |  Company: Uber
# 10. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-05 15:04:18  |  Dropoff: 2022-11-05 15:44:34  |  Company: Uber
# 11. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-05 22:09:45  |  Dropoff: 2022-11-05 22:37:15  |  Company: Lyft
# 12. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-05 22:13:25  |  Dropoff: 2022-11-05 22:48:06  |  Company: Uber
# 13. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-06 00:49:06  |  Dropoff: 2022-11-06 01:14:14  |  Company: Uber
# 14. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-06 07:22:05  |  Dropoff: 2022-11-06 08:11:12  |  Company: Uber
# 15. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-06 08:21:48  |  Dropoff: 2022-11-06 08:47:11  |  Company: Uber
# 16. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-08 11:28:45  |  Dropoff: 2022-11-08 12:06:03  |  Company: Uber
# 17. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-10 03:20:39  |  Dropoff: 2022-11-10 03:48:12  |  Company: Uber
# 18. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-10 07:59:50  |  Dropoff: 2022-11-10 08:35:53  |  Company: Uber
# 19. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-10 12:50:46  |  Dropoff: 2022-11-10 13:26:15  |  Company: Uber
# 20. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-11 07:12:36  |  Dropoff: 2022-11-11 07:37:51  |  Company: Uber
# 21. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-11 17:53:27  |  Dropoff: 2022-11-11 18:43:47  |  Company: Uber
# 22. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-11 23:18:51  |  Dropoff: 2022-11-11 23:45:54  |  Company: Uber
# 23. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-12 02:20:11  |  Dropoff: 2022-11-12 02:44:09  |  Company: Lyft
# 24. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-12 07:11:12  |  Dropoff: 2022-11-12 07:36:34  |  Company: Uber
# 25. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-12 19:30:43  |  Dropoff: 2022-11-12 20:10:57  |  Company: Lyft
# 26. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-12 21:38:51  |  Dropoff: 2022-11-12 22:09:40  |  Company: Uber
# 27. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-13 00:50:21  |  Dropoff: 2022-11-13 01:17:30  |  Company: Uber
# 28. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-13 07:22:25  |  Dropoff: 2022-11-13 07:50:29  |  Company: Uber
# 29. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-13 07:16:23  |  Dropoff: 2022-11-13 07:36:41  |  Company: Uber
# 30. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-13 11:48:26  |  Dropoff: 2022-11-13 12:18:44  |  Company: Uber
# 31. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-13 17:50:35  |  Dropoff: 2022-11-13 18:42:16  |  Company: Uber
# 32. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-13 19:47:47  |  Dropoff: 2022-11-13 20:25:19  |  Company: Uber
# 33. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-14 07:20:32  |  Dropoff: 2022-11-14 08:05:11  |  Company: Uber
# 34. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-14 16:21:56  |  Dropoff: 2022-11-14 17:31:46  |  Company: Lyft
# 35. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-14 17:16:18  |  Dropoff: 2022-11-14 18:31:00  |  Company: Uber
# 36. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-15 22:56:53  |  Dropoff: 2022-11-16 00:01:40  |  Company: Lyft
# 37. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-15 23:19:17  |  Dropoff: 2022-11-15 23:50:21  |  Company: Uber
# 38. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-17 14:35:12  |  Dropoff: 2022-11-17 15:34:18  |  Company: Uber
# 39. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-18 02:19:43  |  Dropoff: 2022-11-18 02:46:48  |  Company: Uber
# 40. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-18 09:04:36  |  Dropoff: 2022-11-18 10:00:13  |  Company: Lyft
# 41. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-18 11:31:36  |  Dropoff: 2022-11-18 12:23:08  |  Company: Uber
# 42. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-18 14:46:22  |  Dropoff: 2022-11-18 16:11:43  |  Company: Uber
# 43. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-19 01:50:24  |  Dropoff: 2022-11-19 02:16:24  |  Company: Uber
# 44. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-19 02:33:27  |  Dropoff: 2022-11-19 03:00:18  |  Company: Uber
# 45. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-19 07:16:24  |  Dropoff: 2022-11-19 07:38:06  |  Company: Uber
# 46. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-19 18:19:16  |  Dropoff: 2022-11-19 19:14:46  |  Company: Uber
# 47. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-19 20:37:17  |  Dropoff: 2022-11-19 21:15:53  |  Company: Lyft
# 48. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-20 07:50:56  |  Dropoff: 2022-11-20 08:12:51  |  Company: Uber
# 49. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-20 09:23:07  |  Dropoff: 2022-11-20 09:49:48  |  Company: Uber
# 50. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-20 13:03:59  |  Dropoff: 2022-11-20 13:44:19  |  Company: Uber
# 51. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-20 16:35:01  |  Dropoff: 2022-11-20 17:24:18  |  Company: Uber
# 52. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-20 20:13:48  |  Dropoff: 2022-11-20 20:49:01  |  Company: Uber
# 53. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-20 23:43:18  |  Dropoff: 2022-11-21 00:12:46  |  Company: Lyft
# 54. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-22 12:21:40  |  Dropoff: 2022-11-22 13:02:01  |  Company: Uber
# 55. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-22 12:47:22  |  Dropoff: 2022-11-22 13:30:24  |  Company: Uber
# 56. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-22 13:19:06  |  Dropoff: 2022-11-22 14:10:29  |  Company: Lyft
# 57. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-22 15:14:22  |  Dropoff: 2022-11-22 16:53:08  |  Company: Uber
# 58. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-22 22:22:12  |  Dropoff: 2022-11-22 22:51:39  |  Company: Lyft
# 59. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-23 00:48:59  |  Dropoff: 2022-11-23 01:14:36  |  Company: Uber
# 60. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-23 17:28:51  |  Dropoff: 2022-11-23 18:51:31  |  Company: Uber
# 61. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-24 06:04:12  |  Dropoff: 2022-11-24 06:29:31  |  Company: Uber
# 62. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-24 08:03:20  |  Dropoff: 2022-11-24 08:28:54  |  Company: Lyft
# 63. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-24 16:57:00  |  Dropoff: 2022-11-24 17:36:33  |  Company: Lyft
# 64. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-24 17:33:52  |  Dropoff: 2022-11-24 18:02:03  |  Company: Uber
# 65. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-24 17:35:29  |  Dropoff: 2022-11-24 18:09:47  |  Company: Lyft
# 66. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-24 18:34:36  |  Dropoff: 2022-11-24 19:04:55  |  Company: Lyft
# 67. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-25 22:09:54  |  Dropoff: 2022-11-25 22:32:57  |  Company: Uber
# 68. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-26 03:24:46  |  Dropoff: 2022-11-26 03:52:27  |  Company: Uber
# 69. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-26 12:43:23  |  Dropoff: 2022-11-26 13:30:40  |  Company: Uber
# 70. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-26 13:44:23  |  Dropoff: 2022-11-26 14:33:09  |  Company: Uber
# 71. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-26 20:57:25  |  Dropoff: 2022-11-26 21:36:23  |  Company: Uber
# 72. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-26 23:47:16  |  Dropoff: 2022-11-27 00:17:26  |  Company: Lyft
# 73. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-26 23:23:31  |  Dropoff: 2022-11-26 23:54:56  |  Company: Lyft
# 74. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-27 07:13:44  |  Dropoff: 2022-11-27 07:34:02  |  Company: Uber
# 75. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-27 08:05:31  |  Dropoff: 2022-11-27 08:36:00  |  Company: Lyft
# 76. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-27 18:54:37  |  Dropoff: 2022-11-27 19:36:38  |  Company: Uber
# 77. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-27 20:36:10  |  Dropoff: 2022-11-27 21:25:09  |  Company: Uber
# 78. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-28 03:02:17  |  Dropoff: 2022-11-28 03:26:41  |  Company: Lyft
# 79. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-28 09:56:11  |  Dropoff: 2022-11-28 10:32:36  |  Company: Uber
# 80. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-28 18:02:48  |  Dropoff: 2022-11-28 18:43:52  |  Company: Uber
# 81. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-29 00:17:10  |  Dropoff: 2022-11-29 00:46:05  |  Company: Uber
# 82. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-29 02:45:28  |  Dropoff: 2022-11-29 03:17:14  |  Company: Uber
# 83. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-29 06:38:23  |  Dropoff: 2022-11-29 07:06:25  |  Company: Uber
# 84. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-29 23:37:31  |  Dropoff: 2022-11-30 00:13:37  |  Company: Uber
# 85. From: Clinton East  →  To: Co-Op City  |  Pickup: 2022-11-30 01:34:48  |  Dropoff: 2022-11-30 02:23:28  |  Company: Uber
